# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadMugiar/WEB_SCRAPPING_KP/blob/main/Cleaning_Data_Scrap_GPLYSTR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMPORT LIBRARY

# %%
import pandas as pd
from datetime import datetime,timedelta
import glob
from google.colab import drive
import numpy as np
from dateutil.relativedelta import relativedelta

# %% [markdown]
# #LOAD DATA

# %%
df =pd.read_csv('/content/drive/MyDrive/DATA_SCRAPPING_GPLAYSTORE_POSE/sentimen_APK_PosPay.csv')
df
# Out:
#                                    reviewId         userName  rate  \
# 0      4f702a1f-ea79-4903-9ad8-0ffbb346d548  Pengguna Google     1
# 1      9a12b861-bfab-4401-86a4-932f66de8e8f  Pengguna Google     1
# 2      06f4ca89-5bce-4f61-805e-954bab0b6058  Pengguna Google     5
# 3      4afc42dc-7a69-496f-9ce0-9f4c50f97c3b  Pengguna Google     1
# 4      6475b3ae-60e4-44bc-9652-cadb5efef0a2  Pengguna Google     5
# ...                                     ...              ...   ...
# 24855  8df6ec3f-e17b-4880-ad17-39ea29c558d8  Pengguna Google     5
# 24856  8e644416-def5-42cd-90ad-22e6a93e3072  Pengguna Google     5
# 24857  3153c402-9175-4f65-b041-a13cb3dbc39c  Pengguna Google     5
# 24858  42c2883b-7808-469f-8463-bfac22699958  Pengguna Google     5
# 24859  968b60a0-9761-4545-973f-bb5f160febab  Pengguna Google     5
#
#                                             reviews_text                 date
# 0      mau masuk akun susah nya minta ampun..data bar...  2025-08-06 05:20:04
# 1      APLIKASI RUSAK. CUMA MENTOK DI MENU AWAL DOANG...  2025-08-06 04:23:17
# 2                                     mudah mengaksesnya  2025-08-06 02:43:53
# 3      aplikasi cacat, proses pendaftarannya sangat b...  2025-08-05 23:18:04
# 4                                mantap dan dan terbukti  2025-08-05 14:59:30
# ...                                                  ...                  ...
# 24855                                          sippp....  2019-04-12 07:15:19
# 24856                                  Bagus aplikasinya  2019-04-12 05:24:47
# 24857                                          good good  2019-04-12 02:21:00
# 24858  mantap. bagus aplikasinya. user friendly. ga r...  2019-04-12 01:58:41
# 24859                                              cakep  2019-04-12 01:18:12
#
# [24860 rows x 5 columns]

# %% [markdown]
# #PROSES CLEANING

# %%
merged_df = df.copy()

# %%
merged_df.info()
merged_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24860 entries, 0 to 24859
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   reviewId      24860 non-null  object
#  1   userName      24860 non-null  object
#  2   rate          24860 non-null  int64
#  3   reviews_text  24860 non-null  object
#  4   date          24860 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 971.2+ KB
#                                reviewId         userName  rate  \
# 0  4f702a1f-ea79-4903-9ad8-0ffbb346d548  Pengguna Google     1
# 1  9a12b861-bfab-4401-86a4-932f66de8e8f  Pengguna Google     1
# 2  06f4ca89-5bce-4f61-805e-954bab0b6058  Pengguna Google     5
# 3  4afc42dc-7a69-496f-9ce0-9f4c50f97c3b  Pengguna Google     1
# 4  6475b3ae-60e4-44bc-9652-cadb5efef0a2  Pengguna Google     5
#
#                                         reviews_text                 date
# 0  mau masuk akun susah nya minta ampun..data bar...  2025-08-06 05:20:04
# 1  APLIKASI RUSAK. CUMA MENTOK DI MENU AWAL DOANG...  2025-08-06 04:23:17
# 2                                 mudah mengaksesnya  2025-08-06 02:43:53
# 3  aplikasi cacat, proses pendaftarannya sangat b...  2025-08-05 23:18:04
# 4                            mantap dan dan terbukti  2025-08-05 14:59:30

# %%
merged_df.drop_duplicates(keep='first',inplace=True)

# %%
for i in merged_df.columns:
    if merged_df[i].dtype=='object':
        merged_df[i]=merged_df[i].str.lower()

# %%
merged_df['date']=merged_df['date'].str.replace('diedit','')

# %%
inidict={
    'sebulan':'1 bulan',
    'setahun':'1 tahun',
    'sehari': '1 hari',
    'seminggu': '1 minggu'
}

# %%
type(inidict),len(inidict),inidict
# Out:
# (dict,
#  4,
#  {'sebulan': '1 bulan',
#   'setahun': '1 tahun',
#   'sehari': '1 hari',
#   'seminggu': '1 minggu'})

# %%
merged_df['date']=merged_df['date'].str.replace('lalu','')

# %%
merged_df['date']=merged_df['date'].str.strip()

# %%
merged_df['date'] = merged_df['date'].map(inidict).fillna(merged_df['date'])

# %%
merged_df['date'].value_counts()
# Out:
# date
# 2021-11-12 02:41:35    2
# 2024-09-02 17:25:34    2
# 2023-04-21 04:32:05    2
# 2022-11-07 11:44:09    2
# 2024-07-22 06:56:43    2
#                       ..
# 2023-04-20 04:04:01    1
# 2023-04-20 04:05:26    1
# 2023-04-20 04:05:53    1
# 2023-04-20 04:06:47    1
# 2023-04-20 03:54:22    1
# Name: count, Length: 24813, dtype: int64

# %%
merged_df['waktu_dalam_angka']=merged_df['date'].str.split(' ').str[0]

# %%
merged_df['waktu_dalam_jam']=merged_df['date'].str.split(' ').str[1]

# %%
merged_df
# Out:
#                                    reviewId         userName  rate  \
# 0      4f702a1f-ea79-4903-9ad8-0ffbb346d548  pengguna google     1
# 1      9a12b861-bfab-4401-86a4-932f66de8e8f  pengguna google     1
# 2      06f4ca89-5bce-4f61-805e-954bab0b6058  pengguna google     5
# 3      4afc42dc-7a69-496f-9ce0-9f4c50f97c3b  pengguna google     1
# 4      6475b3ae-60e4-44bc-9652-cadb5efef0a2  pengguna google     5
# ...                                     ...              ...   ...
# 24855  8df6ec3f-e17b-4880-ad17-39ea29c558d8  pengguna google     5
# 24856  8e644416-def5-42cd-90ad-22e6a93e3072  pengguna google     5
# 24857  3153c402-9175-4f65-b041-a13cb3dbc39c  pengguna google     5
# 24858  42c2883b-7808-469f-8463-bfac22699958  pengguna google     5
# 24859  968b60a0-9761-4545-973f-bb5f160febab  pengguna google     5
#
#                                             reviews_text                 date  \
# 0      mau masuk akun susah nya minta ampun..data bar...  2025-08-06 05:20:04
# 4            2025-08-05        14:59:30
# ...                 ...             ...
# 24855        2019-04-12        07:15:19
# 24856        2019-04-12        05:24:47
# 24857        2019-04-12        02:21:00
# 24858        2019-04-12        01:58:41
# 24859        2019-04-12        01:18:12
#
# [24860 rows x 7 columns]

# %%
merged_df.drop(columns=['date','waktu_dalam_jam'],inplace=True)
merged_df
# Out:
#                                    reviewId         userName  rate  \
# 0      4f702a1f-ea79-4903-9ad8-0ffbb346d548  pengguna google     1
# 1      9a12b861-bfab-4401-86a4-932f66de8e8f  pengguna google     1
# 2      06f4ca89-5bce-4f61-805e-954bab0b6058  pengguna google     5
# 3      4afc42dc-7a69-496f-9ce0-9f4c50f97c3b  pengguna google     1
# 4      6475b3ae-60e4-44bc-9652-cadb5efef0a2  pengguna google     5
# ...                                     ...              ...   ...
# 24855  8df6ec3f-e17b-4880-ad17-39ea29c558d8  pengguna google     5
# 24856  8e644416-def5-42cd-90ad-22e6a93e3072  pengguna google     5
# 24857  3153c402-9175-4f65-b041-a13cb3dbc39c  pengguna google     5
# 24858  42c2883b-7808-469f-8463-bfac22699958  pengguna google     5
# 24859  968b60a0-9761-4545-973f-bb5f160febab  pengguna google     5
#
#                                             reviews_text waktu_dalam_angka
# 0      mau masuk akun susah nya minta ampun..data bar...        2025-08-06
# 1      aplikasi rusak. cuma mentok di menu awal doang...        2025-08-06
# 2                                     mudah mengaksesnya        2025-08-06
# 3      aplikasi cacat, proses pendaftarannya sangat b...        2025-08-05
# 4                                mantap dan dan terbukti        2025-08-05
# ...                                                  ...               ...
# 24855                                          sippp....        2019-04-12
# 24856                                  bagus aplikasinya        2019-04-12
# 24857                                          good good        2019-04-12
# 24858  mantap. bagus aplikasinya. user friendly. ga r...        2019-04-12
# 24859                                              cakep        2019-04-12
#
# [24860 rows x 5 columns]

# %%
merged_df.rename(columns={'waktu_dalam_angka': 'tanggal reviews'}, inplace=True)
merged_df.head()
# Out:
#                                reviewId         userName  rate  \
# 0  4f702a1f-ea79-4903-9ad8-0ffbb346d548  pengguna google     1
# 1  9a12b861-bfab-4401-86a4-932f66de8e8f  pengguna google     1
# 2  06f4ca89-5bce-4f61-805e-954bab0b6058  pengguna google     5
# 3  4afc42dc-7a69-496f-9ce0-9f4c50f97c3b  pengguna google     1
# 4  6475b3ae-60e4-44bc-9652-cadb5efef0a2  pengguna google     5
#
#                                         reviews_text tanggal reviews
# 0  mau masuk akun susah nya minta ampun..data bar...      2025-08-06
# 1  aplikasi rusak. cuma mentok di menu awal doang...      2025-08-06
# 2                                 mudah mengaksesnya      2025-08-06
# 3  aplikasi cacat, proses pendaftarannya sangat b...      2025-08-05
# 4                            mantap dan dan terbukti      2025-08-05

# %%
merged_df.to_csv('Scrapping_Clean_PosPay.csv',index=False)
