# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadMugiar/WEB_SCRAPPING_KP/blob/main/Cleaning_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMPORT LIBRARY

# %%
import pandas as pd
from datetime import datetime,timedelta
import glob
from google.colab import drive
import numpy as np
from dateutil.relativedelta import relativedelta

# %% [markdown]
# #LOAD DATA

# %%
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/DATA_SCRAPPING_GMAPS_POS/'
file_pattern = '*.csv'
all_files = glob.glob(file_path + file_pattern)
list_df = []
for file in all_files:
    df = pd.read_csv(file)
    list_df.append(df)
merged_df = pd.concat(list_df, ignore_index=True)
display(merged_df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                Pos Office Branch                User  \
# 0     Kantor Pos Besar Pontianak           Miss gita
# 1     Kantor Pos Besar Pontianak        Andreas Leon
# 2     Kantor Pos Besar Pontianak  Mella kartika sari
# 3     Kantor Pos Besar Pontianak   Anom Arie Satriya
# 4     Kantor Pos Besar Pontianak          Ana Kiftia
# ...                          ...                 ...
# 1101         Kantor Pos Ketapang   Wahyudi Akuntansi
# 1102         Kantor Pos Ketapang       Yogi Prasetio
# 1103         Kantor Pos Ketapang     Wilbert Orlando
# 1104         Kantor Pos Ketapang            abuFathy
# 1105         Kantor Pos Ketapang          santi chai
#
#                                                 Reviews  Rate           Date
# 0     📍Lokasinya strategis dan mudah ditemukan, teru...     5  2 minggu lalu
# ...

# %% [markdown]
# #PROSES CLEANING

# %%
merged_df.info()
merged_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1106 entries, 0 to 1105
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pos Office Branch  1106 non-null   object
#  1   User               1106 non-null   object
#  2   Reviews            1106 non-null   object
#  3   Rate               1106 non-null   int64
#  4   Date               1106 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 43.3+ KB
#             Pos Office Branch                User  \
# 0  Kantor Pos Besar Pontianak           Miss gita
# 1  Kantor Pos Besar Pontianak        Andreas Leon
# 2  Kantor Pos Besar Pontianak  Mella kartika sari
# 3  Kantor Pos Besar Pontianak   Anom Arie Satriya
# 4  Kantor Pos Besar Pontianak          Ana Kiftia
#
#                                              Reviews  Rate           Date
# 0  📍Lokasinya strategis dan mudah ditemukan, teru...     5  2 minggu lalu
# ...

# %%
merged_df.drop_duplicates(keep='first',inplace=True)

# %%
for i in merged_df.columns:
    if merged_df[i].dtype=='object':
        merged_df[i]=merged_df[i].str.lower()

# %%
merged_df['Date']=merged_df['Date'].str.replace('diedit','')

# %%
inidict={
    'sebulan':'1 bulan',
    'setahun':'1 tahun',
    'sehari': '1 hari',
    'seminggu': '1 minggu'
}

# %%
type(inidict),len(inidict),inidict
# Out:
# (dict,
#  4,
#  {'sebulan': '1 bulan',
#   'setahun': '1 tahun',
#   'sehari': '1 hari',
#   'seminggu': '1 minggu'})

# %%
merged_df['Date']=merged_df['Date'].str.replace('lalu','')

# %%
merged_df['Date']=merged_df['Date'].str.strip()

# %%
merged_df['Date'] = merged_df['Date'].map(inidict).fillna(merged_df['Date'])

# %%
merged_df['Date'].value_counts()
# Out:
# Date
# 6 tahun     140
# 5 tahun     131
# 7 tahun     122
# 2 tahun     110
# 4 tahun     105
# 8 tahun      94
# 3 tahun      89
# 1 tahun      87
# 11 bulan     60
# 9 tahun      24
# 6 bulan      19
# 1 bulan      17
# 2 bulan      14
# 5 bulan      13
# 10 bulan     12
# 7 bulan       9
# 9 bulan       9
# 3 bulan       9
# 8 bulan       8
# 2 minggu      8
# 3 minggu      5
# 4 bulan       5
# 11 tahun      4
# 1 minggu      3
# 4 minggu      3
# 12 tahun      2
# 10 tahun      2
# 4 hari        1
# 5 hari        1
# Name: count, dtype: int64

# %%
merged_df['waktu_dalam_angka']=merged_df['Date'].str.split(' ').str[0]

# %%
merged_df['waktu_dalam_ket']=merged_df['Date'].str.split(' ').str[1]

# %%
merged_df
# Out:
#                Pos Office Branch                User  \
# 0     kantor pos besar pontianak           miss gita
# 1     kantor pos besar pontianak        andreas leon
# 2     kantor pos besar pontianak  mella kartika sari
# 3     kantor pos besar pontianak   anom arie satriya
# 4     kantor pos besar pontianak          ana kiftia
# ...                          ...                 ...
# 1101         kantor pos ketapang   wahyudi akuntansi
# 1102         kantor pos ketapang       yogi prasetio
# 1103         kantor pos ketapang     wilbert orlando
# 1104         kantor pos ketapang            abufathy
# 1105         kantor pos ketapang          santi chai
#
#                                                 Reviews  Rate      Date  \
# 0     📍lokasinya strategis dan mudah ditemukan, teru...     5  2 minggu
# 1     kantor pos yang cukup besar yang pernah saya d...     4   3 bulan
# 2     baru kali ini ke kantor pos besar\nantar ibu a...     5   1 bulan
# ...

# %%
merged_df['waktu_dalam_ket'].value_counts()
# Out:
# waktu_dalam_ket
# tahun     910
# bulan     175
# minggu     19
# hari        2
# Name: count, dtype: int64

# %%
merged_df
# Out:
#                Pos Office Branch                User  \
# 0     kantor pos besar pontianak           miss gita
# 1     kantor pos besar pontianak        andreas leon
# 2     kantor pos besar pontianak  mella kartika sari
# 3     kantor pos besar pontianak   anom arie satriya
# 4     kantor pos besar pontianak          ana kiftia
# ...                          ...                 ...
# 1101         kantor pos ketapang   wahyudi akuntansi
# 1102         kantor pos ketapang       yogi prasetio
# 1103         kantor pos ketapang     wilbert orlando
# 1104         kantor pos ketapang            abufathy
# 1105         kantor pos ketapang          santi chai
#
#                                                 Reviews  Rate      Date  \
# 0     📍lokasinya strategis dan mudah ditemukan, teru...     5  2 minggu
# 1     kantor pos yang cukup besar yang pernah saya d...     4   3 bulan
# 2     baru kali ini ke kantor pos besar\nantar ibu a...     5   1 bulan
# ...

# %%
hariini=datetime.today().date()

# %%
hariini
# Out:
# datetime.date(2025, 8, 11)

# %%
merged_df['waktu_dalam_angka']=merged_df['waktu_dalam_angka'].astype(int)

# %%
def hitung_tanggal(row):
    angka = row['waktu_dalam_angka']
    ket = row['waktu_dalam_ket']
    if ket == 'tahun':
        return hariini - relativedelta(years=angka)
    elif ket == 'bulan':
        return hariini - relativedelta(months=angka)
    elif ket == 'minggu':
        return hariini - relativedelta(weeks=angka)
    elif ket == 'hari':
        return hariini - relativedelta(days=angka)
    else:
        return hariini

merged_df['tanggal_review'] = merged_df.apply(hitung_tanggal, axis=1)

# %%
merged_df.drop(columns=['Date','waktu_dalam_angka','waktu_dalam_ket'],inplace=True)
merged_df
# Out:
#                Pos Office Branch                User  \
# 0     kantor pos besar pontianak           miss gita
# 1     kantor pos besar pontianak        andreas leon
# 2     kantor pos besar pontianak  mella kartika sari
# 3     kantor pos besar pontianak   anom arie satriya
# 4     kantor pos besar pontianak          ana kiftia
# ...                          ...                 ...
# 1101         kantor pos ketapang   wahyudi akuntansi
# 1102         kantor pos ketapang       yogi prasetio
# 1103         kantor pos ketapang     wilbert orlando
# 1104         kantor pos ketapang            abufathy
# 1105         kantor pos ketapang          santi chai
#
#                                                 Reviews  Rate tanggal_review
# 0     📍lokasinya strategis dan mudah ditemukan, teru...     5     2025-07-28
# 1     kantor pos yang cukup besar yang pernah saya d...     4     2025-05-11
# 2     baru kali ini ke kantor pos besar\nantar ibu a...     5     2025-07-11
# ...
